# %%
import pandas as pd
import numpy as np

from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.isnull().sum()
# Out:
# id                    0
# an                    0
# materie               0
# liceu                 0
# judet                 0
# medie                 0
# procent_reusita       0
# numar_candidati       0
# preferinta_materie    0
# anomalie              0
# dtype: int64

# %%
frm_sub1 = df_test[(df_test['liceu'] == 'COLEGIUL NATIONAL "UNIREA" FOCSANI') & ( df_test['materie'] != 'LIMBA ROMANA')]

# %%
frm_sub1['materie'].unique()
# Out:
# array(['ANATOMIE SI FIZIOLOGIE UMANA, GENETICA SI ECOLOGIE UMANA',
#        'BIOLOGIE VEGETALA SI ANIMALA', 'CHIMIE ORGANICA TEO NIVEL I-II',
#        'ECONOMIE', 'FILOSOFIE', 'FIZICA TEO', 'GENERAL', 'GEOGRAFIE',
#        'INFORMATICA MI C-C++', 'INFORMATICA SN C-C++', 'ISTORIE',
#        'LOGICA, ARGUMENTARE SI COMUNICARE', 'MATEMATICA MATE-INFO',
#        'MATEMATICA ST-NAT', 'PSIHOLOGIE'], dtype=object)

# %%
sub1 = frm_sub1['materie'].mode()[0]

# %%
frm_sub2 = df_train[df_train['materie'] =='INFORMATICA MI C-C++']

# %%
sub2 = frm_sub2['preferinta_materie'].idxmax()
