# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
df_train = pd.read_csv('data.csv')

# %%
df_train
# Out:
#       RoundID  skill_level  teamwork_score  puzzle_intuition  \
# 0           0    61.174814       58.879307          1.604486
# 1           1    58.133589       58.039304          1.588768
# 2           2    59.697344       57.087653          1.226585
# 3           3    59.996048       57.537453          1.685187
# 4           4    60.066185       58.342768          1.068056
# ...       ...          ...             ...               ...
# 3995     3995    72.420116       64.336370          1.369448
# 3996     3996    73.152653       65.320541          1.221737
# 3997     3997    71.692068       64.316157          1.085214
# 3998     3998    72.642119       65.645959          1.085016
# 3999     3999    60.565200       54.307131          1.185941
#
#       arcane_knowledge  focus_level  strategy_depth           location  \
# 0            -3.356868    54.648389       51.830036       Crystal Cave
# 1            -3.556428    53.020806       45.971086     Rooftop Garden
# 2             7.152169    53.011371       48.309135     Rooftop Garden
# 3             9.359777    50.653686       46.579880       Crystal Cave
# 4            -4.594134    54.653283       50.473253      Mystic Bridge
# ...                ...          ...             ...                ...
# 3995         31.066748    53.131416       50.377112    The Old Library
# 3996         24.575675    49.325738       51.856636  Abandoned Theater
# 3997         33.694446    51.786323       53.893343  Abandoned Theater
# 3998         21.985233    51.307810       55.173287  Abandoned Theater
# 3999         -8.589375    51.616162       50.207057       Crystal Cave
#
#      puzzle_type secret_mechanism          story_arc  tech_assist  night_mode  \
# 0          Logic      Ancient Map    Forbidden Magic            1           1
# 1           Maze        Magic Key  Lost Civilization            0           1
# 2       Sequence        Magic Key    Cursed Treasure            1           1
# 3           Maze      Ancient Map  Lost Civilization            1           1
# 4       Sequence    Teleport Rune    Forbidden Magic            0           1
# ...          ...              ...                ...          ...         ...
# 3995  Mechanical    Teleport Rune  Lost Civilization            1           1
# 3996    Sequence      Ancient Map  Lost Civilization            1           1
# 3997  Mechanical    Teleport Rune    Forbidden Magic            1           1
# 3998      Symbol      Ancient Map   Ancient Prophecy            0           1
# 3999      Symbol    Teleport Rune    Forbidden Magic            1           0
#
#       mystery_power  team_synergy  focus_magic  style
# 0         36.831020     51.201478    34.967259     -1
# 1         33.492061     53.257079    35.649418     -1
# 2         38.773553     50.167258    32.095970     -1
# 3         39.509380     50.588093    32.026528     -1
# 4         33.643430     53.205376    33.049910     -1
# ...             ...           ...          ...    ...
# 3995      55.011396     56.025863    30.580337     -1
# 3996      51.794363     54.346350    26.994405     -1
# 3997      54.356577     57.746747    29.876157     -1
# 3998      51.810088     58.940741    28.997413     -1
# 3999      34.474256     50.199870    26.756765     -1
#
# [4000 rows x 17 columns]

# %%
frm_s1 = df_train[(df_train['location'] == 'The Old Library') & (df_train['tech_assist'] == 1)]

# %%
sub1 = len(frm_s1)
